# %% [markdown]
# # Exercise 06 - Container

# %% [markdown]
# ## List

# %% [markdown]
# **Exercise 1:**
#
# Write two ways to create an empty list.

# %%
list_one = []

list_two = list()

print(list_one)
# Out:
# []

# %% [markdown]
# **Exercise 1.1:**
#
# Now add the following values to the list in **1** and print the list.
#
# `"test", 1, 2, "hello", True, False, None`

# %%
my_list = []

my_list.append("test")
my_list.append(1)
my_list.append(2)
my_list.append("hello")
my_list.append(True)
my_list.append(False)
my_list.append(None)


print(my_list)
# Out:
# ['test', 1, 2, 'hello', True, False, None]

# %% [markdown]
# **Exercise 1.2:**
#
# Now add the following list of values to the list in **1.1** and print the list.

# %%
values_to_add = ["a", "list", "of", "values"]

# %%
my_list.extend(values_to_add)

print(my_list)
# Out:
# ['test', 1, 2, 'hello', True, False, None, 'a', 'list', 'of', 'values']

# %% [markdown]
# **Exercise 1.3:**
#
# How long is the list create in **1.2**?

# %%
print(len(my_list))
# Out:
# 11

# %% [markdown]
# **Exercise 1.4:**
#
# Repeat the list from **1.2** 2x times.

# %%
repeated_list = my_list * 2
print(repeated_list)
# Out:
# ['test', 1, 2, 'hello', True, False, None, 'a', 'list', 'of', 'values', 'test', 1, 2, 'hello', True, False, None, 'a', 'list', 'of', 'values']

# %% [markdown]
# **Exercise 1.5:**
#
# Try to sort the list of **1.2**. What happens and why?

# %%
my_list.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 my_list.sort()
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %% [markdown]
# I got an error that says: TypeError: '<' not supported between instances of 'int' and 'str'

# %% [markdown]
# => **Write down your ideas/thoughts here:**
#
# I think this happened because ...
#
# This happened because my_list contains a mix of different data types, including numbers and text strings.

# %% [markdown]
# **Exercise 1.6:**
#
# Sorting a list.
#
# There are two ways to do so:
# 1. By creating a sorted copy of the original list.
# 2. By sorting the original list in-place.

# %%
a_list = [6, 4, 3, 7, 9, 0, 7, 10, 170, 49]

# %% [markdown]
# 1. First, sort the list while creating a new, sorted copy. After sorting, print the original list to check that you did not modify it.

# %%
new_sorted_list = sorted(a_list)

print("Sorted copy:", new_sorted_list)


print("Original list:", a_list)
# Out:
# Sorted copy: [0, 3, 4, 6, 7, 7, 9, 10, 49, 170]
# Original list: [6, 4, 3, 7, 9, 0, 7, 10, 170, 49]

# %% [markdown]
# 2. Now, sort the original list without creating a copy (which is called an **in-place sort**). After sorting, print the original list to check that you did modify it.

# %%
a_list.sort()


print("Modified original list:", a_list)
# Out:
# Modified original list: [0, 3, 4, 6, 7, 7, 9, 10, 49, 170]

# %% [markdown]
# **Exercise 1.7:**
#
# Create two list with different values and length and compare them for `equality`, `inequality`, `less than`, and `greater than`.

# %%
# Create your lists here
list_A = [1, 2, 3]
list_B = [1, 2, 5, 6]  # Different values and longer length
print("Lists initialized.")
# Out:
# Lists initialized.

# %%
# Equality
print("Is list_A equal to list_B?", list_A == list_B)
# Out:
# Is list_A equal to list_B? False

# %%
# Inequality
print("Is list_A not equal to list_B?", list_A != list_B)
# Out:
# Is list_A not equal to list_B? True

# %%
# Less than
print("Is list_A less than list_B?", list_A < list_B)
print("Is list_A greater than list_B?", list_A > list_B)
# Out:
# Is list_A less than list_B? True
# Is list_A greater than list_B? False

# %% [markdown]
# **Exercise 1.8:**
#
# Given the following list, replace values at index positions `1, 4, 6` with `0`.

# %%
alist = ['a', 2, 'b', 5, 6, 'c', 'h']

# %%
alist[1] = 0
alist[4] = 0
alist[6] = 0


print(alist)
# Out:
# ['a', 0, 'b', 5, 0, 'c', 0]

# %% [markdown]
# ## Set

# %% [markdown]
# **Exercise 3:**
#
# Create a set called `new_set` storing the values `6, 4, 3, 7, 9, 0, 7, 10, 170, 49, 0, 10, 4`.

# %%
new_set = {6, 4, 3, 7, 9, 0, 7, 10, 170, 49, 0, 10, 4}

print(new_set)
# Out:
# {0, 3, 4, 6, 7, 9, 10, 170, 49}

# %% [markdown]
# **Exercise 3.1:**
#
# Determine the number of elements in the set from **3**.

# %%
print(len(new_set))
# Out:
# 9

# %% [markdown]
# **Exercise 3.2:**
#
# Create an empty set.

# %%
empty_set = set()
print(type(empty_set))
# Out:
# <class 'set'>

# %% [markdown]
# **Exercise 3.3:**
#
# Update the set from **3.1** with the new values `True, False, "Hello", 0, None, 1`.

# %% [markdown]
# 1. But first... What do you think will be the length of the updated set?

# %% [markdown]
# Your answer: ...

# %% [markdown]
# I think the length will increase by only 2 items. This is because Hello and None are new entries, but Python treats False and 0 as duplicates, and True and 1 as duplicates, so it will ignore the extra repetitions.

# %% [markdown]
# 2. Now add the values and check the length.

# %%
new_set.update([True, False, "Hello", 0, None, 1])


print("Updated set items:", new_set)
print("Final length:", len(new_set))
# Out:
# Updated set items: {0, True, None, 3, 4, 6, 7, 9, 10, 170, 49, 'Hello'}
# Final length: 12

# %% [markdown]
# **Exercise 3.4:**
#
# 1. Remove the value `10` from the set in **3.3**.

# %%
new_set.remove(10)
print(new_set)
# Out:
# {0, True, None, 3, 4, 6, 7, 9, 170, 49, 'Hello'}

# %% [markdown]
# 2. Try to remove `10` again, what happens?

# %%
new_set.remove(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 new_set.remove(10)
#
# KeyError: 10

# %% [markdown]
# KeyError: 10 -- this error appeared.

# %% [markdown]
# 3. Remove the values `10` and `exercise` from the set without raising an error.

# %%
new_set.discard(10)
new_set.discard("exercise")

print("Safe removal finished. Current set:", new_set)
# Out:
# Safe removal finished. Current set: {0, True, None, 3, 4, 6, 7, 9, 170, 49, 'Hello'}

# %% [markdown]
# **Exercise 3.5**
#
# Create two sets with `1,2,3,5,6` and `3,5,6,7,8` and build the intersection of the two.
#
# Which values will be in the final set?

# %% [markdown]
# Your answer: ...

# %%
set_A = {1, 2, 3, 5, 6}
set_B = {3, 5, 6, 7, 8}

common_items = set_A.intersection(set_B)
print("Intersection result:", common_items)
# Out:
# Intersection result: {3, 5, 6}

# %% [markdown]
# ## Dict

# %% [markdown]
# **Exercise 4:**
#
# Create a dictionary with at least 5 key,value pairs of various data types (not only strings or integers) and save it in a variable called `dictionary`.

# %%
dictionary = {
    "name": "Vesuvius",
    "elevation_m": 1281,
    "active": True,
    "last_eruption": 1944.0,
    "hazards": ["lava", "ash", "pyroclastic flow"]
}

print(dictionary)
# Out:
# {'name': 'Vesuvius', 'elevation_m': 1281, 'active': True, 'last_eruption': 1944.0, 'hazards': ['lava', 'ash', 'pyroclastic flow']}

# %% [markdown]
# **Exercise 4.1:**
#
# Create the same dict as in **4** but this time from a list of tuples.

# %%
tuple_list = [
    ("name", "Vesuvius"),
    ("elevation_m", 1281),
    ("active", True),
    ("last_eruption", 1944.0),
    ("hazards", ["lava", "ash", "pyroclastic flow"])
]


dictionary_from_tuples = dict(tuple_list)
print(dictionary_from_tuples)
# Out:
# {'name': 'Vesuvius', 'elevation_m': 1281, 'active': True, 'last_eruption': 1944.0, 'hazards': ['lava', 'ash', 'pyroclastic flow']}

# %% [markdown]
# **Exercise 4.2:**
#
# Retrieve 3 different keys from `dictionary` in **4**.

# %%
val1 = dictionary["name"]
val2 = dictionary["elevation_m"]
val3 = dictionary["active"]

print(val1, val2, val3)
# Out:
# Vesuvius 1281 True

# %% [markdown]
# **Exercise 4.3:**
#
# Create a dictionary given the following tuples `[(1, True), (2, 'Hi'), (True, False)]`.

# %%
tricky_tuples = [(1, True), (2, 'Hi'), (True, False)]
result_dict = dict(tricky_tuples)

print(result_dict)
# Out:
# {1: False, 2: 'Hi'}

# %% [markdown]
# Question: What can you observe?

# %% [markdown]
# the key 1 disappears, and your final dictionary only has 2 items.

# %% [markdown]
# Your answer: ... The key `1` and `True` map to the same entry in the dictionary. This happens because `1==True`.

# %% [markdown]
# **Exercise 4.4:**
#
# Use your dictionary from **4** and add 3 new key,value pairs to it.

# %%
dictionary["country"] = "Italy"
dictionary["status"] = "monitored"
dictionary["type"] = "stratovolcano"

print(dictionary)
# Out:
# {'name': 'Vesuvius', 'elevation_m': 1281, 'active': True, 'last_eruption': 1944.0, 'hazards': ['lava', 'ash', 'pyroclastic flow'], 'country': 'Italy', 'status': 'monitored', 'type': 'stratovolcano'}

# %% [markdown]
# **Exercise 4.5:**
#
# Use you dict from **4** and check if the key `2` is included in the dictionary. Also check if `Hi` is not included in the dictionary.

# %%
check_key = 2 in dictionary
print("Is key 2 in the dictionary?", check_key)

check_value_as_key = "Hi" not in dictionary
print("Is 'Hi' absent from the keys?", check_value_as_key)
# Out:
# Is key 2 in the dictionary? False
# Is 'Hi' absent from the keys? True

# %% [markdown]
# **Exercise 4.6:**
#
# Get a list of all keys in the dictionary from **4**. Also get a list of all values in the dictionary.

# %%
all_keys = list(dictionary.keys())
all_values = list(dictionary.values())

print("Keys list:", all_keys)
print("Values list:", all_values)
# Out:
# Keys list: ['name', 'elevation_m', 'active', 'last_eruption', 'hazards', 'country', 'status', 'type']
# Values list: ['Vesuvius', 1281, True, 1944.0, ['lava', 'ash', 'pyroclastic flow'], 'Italy', 'monitored', 'stratovolcano']

# %% [markdown]
# ## (Optional) Tuple

# %% [markdown]
# **Exercise 2:**
#
# Create an empty tuple.

# %%
empty_tuple = ()
print(type(empty_tuple))
# Out:
# <class 'tuple'>

# %% [markdown]
# **Exercise 2.1:**
#
# Create a tuple with the values `6, 4, 3, 7, 9, 0, 7, 10, 170, 49`

# %%
my_tuple = (6, 4, 3, 7, 9, 0, 7, 10, 170, 49)
print(my_tuple)
# Out:
# (6, 4, 3, 7, 9, 0, 7, 10, 170, 49)

# %% [markdown]
# **Exercise 2.2:**
#
# Print the values at index `1,2,3,4`.

# %%
sliced_values = my_tuple[1:5]
print(sliced_values)
# Out:
# (4, 3, 7, 9)

# %% [markdown]
# Print the last value from the tuple in **2.1**.

# %%
last_value = my_tuple[-1]
print(last_value)
# Out:
# 49

# %% [markdown]
# **Exercise 2.3:**
#
# Create a new tuple with some values and combine it with the tuple you created in **2.1**.

# %%
another_tuple = (99, 100, 101)


combined_tuple = my_tuple + another_tuple

print(combined_tuple)
# Out:
# (6, 4, 3, 7, 9, 0, 7, 10, 170, 49, 99, 100, 101)
