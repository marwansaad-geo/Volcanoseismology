# %% [markdown]
# # Exercise 13 - Matplotlib & Seaborn
#
# ## Plotting data
#
# In this exercise you will load some data and use various techniques to plot it.
#
# **Exercise 1:**
#
# In this excercise you will create a figure with 3 `Axes`, one per row, with `Matplotlib`. All axes will share their x-axis. The figure size will be set to `(6, 6)`. You will then plot data from ` lecture_13/station.dat` with line plots, add axis labels, grids, and add a vertical line.
#
# 1. Import the necessary packages

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# 2. Load the data from "lecture_13/station.dat"

# %%
data = np.loadtxt("lecture_13/station.dat")
time = data[:, 0]
north_south = data[:, 1]
east_west = data[:, 2]
up_down = data[:, 3]

# %% [markdown]
# 3. Recreate the following figure
# ![](lecture_13/excercise_task_1_figure.png)

# %%
fig, axs = plt.subplots(3, 1, figsize=(6, 6), sharex=True)

axs[0].plot(time, north_south)
axs[0].set_ylabel("North-South")
axs[0].grid(True)

axs[1].plot(time, east_west)
axs[1].set_ylabel("East-West")
axs[1].axvline(x=30, color="red")
axs[1].grid(True)

axs[2].plot(time, up_down)
axs[2].set_ylabel("Up-Down")
axs[2].set_xlabel("Time: Zero to 49.98s")
axs[2].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Excercise 2:**
#
# In this exercise you will create some randomly distributed data with `NumPy`. You will then plot this data with `Seaborn`.
#
# 1. Import the necessary packages

# %%
# %pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\marwan\anaconda3\envs\clean_geo\lib\site-packages (from seaborn) (2.2.6)
# Requirement already satisfied: pandas>=1.2 in c:\users\marwan\anaconda3\envs\clean_geo\lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\marwan\anaconda3\envs\clean_geo\lib\site-packages (from seaborn) (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\marwan\anaconda3\envs\clean_geo\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\marwan\anaconda3\envs\clean_geo\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\marwan\anaconda3\envs\clean_geo\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\marwan\anaconda3\envs\clean_geo\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\marwan\anaconda3\envs\clean_geo\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.2)
# Requirement already satisfied: pillow>=8 in c:\users\marwan\anaconda3\envs\clean_geo\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\marwan\anaconda3\envs\clean_geo\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\marwan\anaconda3\envs\clean_geo\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\marwan\anaconda3\envs\clean_geo\lib\site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\marwan\anaconda3\envs\clean_geo\lib\site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: six>=1.5 in c:\users\marwan\anaconda3\envs\clean_geo\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# 2. Create three randomly distributed datatasets
#
# - x = 500 samples, low=-6, high=8, uniform distribution
# - x2 = 1000 samples, Mean of the distribution = 5.0, normal distribution
# - x3 = 2000 samples, Mean of the distribution = -3.5, normal distribution

# %%
# DO NOT CHANGE. This is so that you get the same results as in the figure.
import numpy as np
np.random.seed(0)

# %%
x = np.random.uniform(-6, 8, 500)
x2 = np.random.normal(5.0, 1.0, 1000)
x3 = np.random.normal(-3.5, 1.0, 2000)

# %% [markdown]
# 3. Recreate the following figure
#
# ![](lecture_13/excercise_task_2_figure.png)
#
# Note: Bins are set to auto.

# %%
plt.figure(figsize=(6, 4))

sns.histplot(x, color="tab:blue", alpha=0.5, label="Uniform")
sns.histplot(x2, color="tab:orange", alpha=0.5, label="Normal (Mean=5.0)")
sns.histplot(x3, color="tab:green", alpha=0.5, label="Normal (Mean=-3.5)")

plt.xlabel("Value")
plt.ylabel("Occurrence")

plt.show()

# %% [markdown]
# You can see that green and orange are normal, also called gaussian, distributed and that the blue data is uniformly distributed across the value range.
