# %% [markdown]
# # Exercise 03 - Strings, Integers, Floats, Bool, None

# %% [markdown]
# **Exercise 1:**
#
# Create a variable for each data type (str, int, float, bool, none) and store a value from that type in the variable.

# %%
my_string = "Hello Geo"
my_integer = 25
my_float = 14.8
my_boolean = True
my_empty = None

# %% [markdown]
# **Exercise 2:**
#
# Output one of the variables you have created in **Exercise 1**.

# %%
print(my_string)
# Out:
# Hello Geo

# %% [markdown]
# **Exercise 3:**
#
# 1. Given the integer `104`, convert it into a string.

# %%
my_string = str(104)
print(type(my_string))
# Out:
# <class 'str'>

# %% [markdown]
# 2. Given the float `10.6`, convert it into an integer.

# %%
my_integer = int(10.6)
print(my_integer)
# Out:
# 10

# %% [markdown]
# 3. Given the string `10.6`, convert it into a float.

# %%
my_float = float("10.6")
print(my_float)
# Out:
# 10.6

# %% [markdown]
# 4. Given the string `100`, convert it into an integer.

# %%
my_integer = int("100")
print(my_integer)
# Out:
# 100

# %% [markdown]
# 5. Given the boolean `False`, convert it into an integer. What happens, if it would be `True` instead?

# %%
bool_false = False
print(int(bool_false))

bool_true = True
print(int(bool_true))
# Out:
# 0
# 1

# %% [markdown]
# **Exercise 3:**
#
# 1. Compute $\frac{(a*b+c)}{3}$ with `a=5`, `b=10`, `c=7`

# %%
a = 5
b = 10
c = 7

fraction_result = (a * b + c) / 3
print(fraction_result)
# Out:
# 19.0

# %% [markdown]
# 2. Compute the remainder of $a-b$ divided by $c$

# %%
a = 5
b = 10
c = 7

remainder_result = (a - b) % c
print(remainder_result)
# Out:
# 2

# %% [markdown]
# 3. Compute $2^{b+c}$

# %%
b = 10
c = 7

power_result = 2 ** (b + c)
print(power_result)
# Out:
# 131072

# %% [markdown]
# 4. Compute the floored result of dividing $b$ by $c$

# %%
b = 10
c = 7

floor_result = b // c
print(floor_result)
# Out:
# 1

# %% [markdown]
# **Exercise 4:**
#
# 1. Concatenate the following three strings `Geophysics`, `is`, and `great`.

# %%
str1 = "Geophysics"
str2 = "is"
str3 = "great"

sentence = str1 + " " + str2 + " " + str3 + "."
print(sentence)
# Out:
# Geophysics is great.

# %% [markdown]
# 2. Repeat the string `Hello` 4 times

# %%
word = "Hello"
result = word * 4
print(result)
# Out:
# HelloHelloHelloHello

# %% [markdown]
# 3. Repeat `Great` 6 times and add spaces between each repetition (no space at the end!).

# %%
word_with_space = "Great "

repeated_words = word_with_space * 6

final_result = repeated_words.strip()

print(final_result)
# Out:
# Great Great Great Great Great Great
