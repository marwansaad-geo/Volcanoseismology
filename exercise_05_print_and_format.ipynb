# %% [markdown]
# # Exercise 05 - Print and Format

# %% [markdown]
# **Exercise 1:**
#
# Print the following variables. One variable per line.

# %%
my_string = "test"
my_integer = 10
my_float = 12.0
my_bool = True
my_none = None

# %% [markdown]
# Enter your solution in the cell below.

# %%
print(my_string)
print(my_integer)
print(my_float)
print(my_bool)
print(my_none)
# Out:
# test
# 10
# 12.0
# True
# None

# %% [markdown]
# **Exercise 2:**
#
# Print the following variables. All on one line and separated by a "-".

# %%
my_string = "test"
my_integer = 10
my_float = 12.0
my_bool = True
my_none = None

# %% [markdown]
# Enter your solution in the cell below.

# %%
print(my_string, my_integer, my_float, my_bool, my_none, sep="-")
# Out:
# test-10-12.0-True-None

# %% [markdown]
# **Exercise 3:**
#
# Print the following variables with **a single print statement** and one variable per line.

# %%
my_string = "test"
my_integer = 10
my_float = 12.0
my_bool = True
my_none = None

# %% [markdown]
# Enter your solution in the cell below.

# %%
print(my_string, my_integer, my_float, my_bool, my_none, sep="\n")
# Out:
# test
# 10
# 12.0
# True
# None

# %% [markdown]
# **Exercise 4:**
#
# Replace "____" in the sentence below with the correct variables also provided below and print it.
#
# Use the f-String syntax to do so.

# %%
rupture = "rupture"
our_planet = "Earth"
common_volcano_place = "underwater"
number_of_plates = 17
liquid_rock = "hot lava"

# %%
# Edit this
sentence = ("A volcano is a ____ in the crust of a planetary-mass object, such as "
           "Earth, that allows ____, volcanic ash, and gases to escape from a magma "
           "chamber below the surface. Earth's volcanoes occur because its crust is broken "
           "into ____ major, rigid tectonic plates that float on a hotter, softer layer in "
           "its mantle. Therefore, on ____, volcanoes are generally found where tectonic "
           "plates are diverging or converging, and most are found ____.")

# %% [markdown]
# Print the sentence below.

# %%
sentence = f"A volcano is a {rupture} in the crust of a planetary-mass object, such as {our_planet}, that allows {liquid_rock}, volcanic ash, and gases to escape from a magma chamber below the surface. Earth's volcanoes occur because its crust is broken into {number_of_plates} major, rigid tectonic plates that float on a hotter, softer layer in its mantle. Therefore, on {our_planet}, volcanoes are generally found where tectonic plates are diverging or converging, and most are found {common_volcano_place}."

print(sentence)
# Out:
# A volcano is a rupture in the crust of a planetary-mass object, such as Earth, that allows hot lava, volcanic ash, and gases to escape from a magma chamber below the surface. Earth's volcanoes occur because its crust is broken into 17 major, rigid tectonic plates that float on a hotter, softer layer in its mantle. Therefore, on Earth, volcanoes are generally found where tectonic plates are diverging or converging, and most are found underwater.
